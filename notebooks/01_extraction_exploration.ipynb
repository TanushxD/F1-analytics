# %%
# Cell 1
import sys
import os
sys.path.append(os.path.abspath(".."))

# %%
# Cell 2
from src.extract import run_extraction

# %%
import pandas as pd

drivers_df = pd.read_csv("../data/raw/F1_drivers.csv")
drivers_df.head()
# Out:
#             Driver     Nationality  \
# 0    Oscar Piastri       Australia
# 1  Alexander Albon        Thailand
# 2     Lando Norris  United Kingdom
# 3   George Russell  United Kingdom
# 4  Charles Leclerc          Monaco
#
#                                              Seasons  Championships  \
# 0                           [2023, 2024, 2025, 2026]              0
# 1         [2019, 2020, 2022, 2023, 2024, 2025, 2026]              0
# 2   [2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026]              1
# 3   [2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026]              0
# 4  [2018, 2019, 2020, 2021, 2022, 2023, 2024, 202...              0
#
#    Race_Entries  Race_Starts  Pole_Positions  Race_Wins  Podiums  \
# 0            73           71               6          9       27
# 1           133          130               0          0        2
# 2           155          154              16         11       44
# 3           155          155               8          6       26
# ...

# %%
print(drivers_df.dtypes)
print("---")
print(drivers_df.isnull().sum())
# Out:
# Driver                    str
# Nationality               str
# Seasons                   str
# Championships           int64
# Race_Entries            int64
# Race_Starts             int64
# Pole_Positions          int64
# Race_Wins               int64
# Podiums                 int64
# Fastest_Laps            int64
# Points                float64
# Active                   bool
# Championship Years        str
# Decade                  int64
# Pole_Rate             float64
# Start_Rate            float64
# Win_Rate              float64
# Podium_Rate           float64
# FastLap_Rate          float64
# Points_Per_Entry      float64
# Years_Active            int64
# Champion                 bool
# dtype: object
# ---
# Driver                  0
# Nationality             0
# Seasons                 0
# Championships           0
# Race_Entries            0
# Race_Starts             0
# Pole_Positions          0
# Race_Wins               0
# Podiums                 0
# ...

# %%
print(drivers_df[drivers_df.astype(str).apply(lambda col: col.str.contains(r'\\N', na=False)).any(axis=1)].head())
# Out:
# Empty DataFrame
# Columns: [Driver, Nationality, Seasons, Championships, Race_Entries, Race_Starts, Pole_Positions, Race_Wins, Podiums, Fastest_Laps, Points, Active, Championship Years, Decade, Pole_Rate, Start_Rate, Win_Rate, Podium_Rate, FastLap_Rate, Points_Per_Entry, Years_Active, Champion]
# Index: []
#
# [0 rows x 22 columns]

# %%
import sys, os
sys.path.append(os.path.abspath(".."))

from src.transform import clean_nulls

drivers_clean = clean_nulls(drivers_df)
print(drivers_clean.isnull().sum())
# Out:
# Driver                  0
# Nationality             0
# Seasons                 0
# Championships           0
# Race_Entries            0
# Race_Starts             0
# Pole_Positions          0
# Race_Wins               0
# Podiums                 0
# Fastest_Laps            0
# Points                  0
# Active                  0
# Championship Years    841
# Decade                  0
# Pole_Rate               0
# Start_Rate              0
# Win_Rate                0
# Podium_Rate             0
# FastLap_Rate            0
# Points_Per_Entry        0
# Years_Active            0
# Champion                0
# dtype: int64

# %%
from src.transform import parse_lap_time

test_cases = ["1:23.456", "23.456", "\\N", None, "", "0:59.999"]
for t in test_cases:
    print(t, "->", parse_lap_time(t))
# Out:
# 1:23.456 -> 83456
# 23.456 -> 23456
# \N -> nan
# None -> nan
#  -> nan
# 0:59.999 -> 59999

# %%
print(drivers_df.columns.tolist())
# Out:
# ['Driver', 'Nationality', 'Seasons', 'Championships', 'Race_Entries', 'Race_Starts', 'Pole_Positions', 'Race_Wins', 'Podiums', 'Fastest_Laps', 'Points', 'Active', 'Championship Years', 'Decade', 'Pole_Rate', 'Start_Rate', 'Win_Rate', 'Podium_Rate', 'FastLap_Rate', 'Points_Per_Entry', 'Years_Active', 'Champion']

# %%
results_df = pd.read_csv("../data/raw/F1_results.csv")  # adjust filename to match what you actually have
results_df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 results_df = pd.read_csv("../data/raw/F1_results.csv")  # adjust filename to match what you actually have
#       2 results_df.head()
#
# File ~\Music\F1-analytics\venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
# ...

# %%
import pandas as pd

drivers_df = pd.read_csv("../data/raw/F1_drivers.csv")
print(drivers_df.columns.tolist())
# Out:
# ['Driver', 'Nationality', 'Seasons', 'Championships', 'Race_Entries', 'Race_Starts', 'Pole_Positions', 'Race_Wins', 'Podiums', 'Fastest_Laps', 'Points', 'Active', 'Championship Years', 'Decade', 'Pole_Rate', 'Start_Rate', 'Win_Rate', 'Podium_Rate', 'FastLap_Rate', 'Points_Per_Entry', 'Years_Active', 'Champion']

# %%
pd.set_option('display.max_columns', None)
drivers_df.head(10)
# Out:
#              Driver     Nationality  \
# 0     Oscar Piastri       Australia
# 1   Alexander Albon        Thailand
# 2      Lando Norris  United Kingdom
# 3    George Russell  United Kingdom
# 4   Charles Leclerc          Monaco
# 5      Pierre Gasly          France
# 6      Lance Stroll          Canada
# 7      Esteban Ocon          France
# 8  Carlos Sainz Jr.           Spain
# 9    Max Verstappen     Netherlands
#
#                                              Seasons  Championships  \
# 0                           [2023, 2024, 2025, 2026]              0
# 1         [2019, 2020, 2022, 2023, 2024, 2025, 2026]              0
# 2   [2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026]              1
# 3   [2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026]              0
# 4  [2018, 2019, 2020, 2021, 2022, 2023, 2024, 202...              0
# 5  [2017, 2018, 2019, 2020, 2021, 2022, 2023, 202...              0
# 6  [2017, 2018, 2019, 2020, 2021, 2022, 2023, 202...              0
# ...

# %%
print(drivers_df.dtypes)
print("---")
print(drivers_df.isnull().sum())
print("---")
print(drivers_df.shape)
# Out:
# Driver                    str
# Nationality               str
# Seasons                   str
# Championships           int64
# Race_Entries            int64
# Race_Starts             int64
# Pole_Positions          int64
# Race_Wins               int64
# Podiums                 int64
# Fastest_Laps            int64
# Points                float64
# Active                   bool
# Championship Years        str
# Decade                  int64
# Pole_Rate             float64
# Start_Rate            float64
# Win_Rate              float64
# Podium_Rate           float64
# FastLap_Rate          float64
# Points_Per_Entry      float64
# Years_Active            int64
# Champion                 bool
# dtype: object
# ---
# Driver                  0
# Nationality             0
# Seasons                 0
# Championships           0
# Race_Entries            0
# Race_Starts             0
# Pole_Positions          0
# Race_Wins               0
# Podiums                 0
# ...

# %%
mask = drivers_df.astype(str).apply(lambda col: col.str.contains(r'\\N', na=False)).any(axis=1)
print(f"Rows containing \\N: {mask.sum()}")
drivers_df[mask].head()
# Out:
# Rows containing \N: 0
# Empty DataFrame
# Columns: [Driver, Nationality, Seasons, Championships, Race_Entries, Race_Starts, Pole_Positions, Race_Wins, Podiums, Fastest_Laps, Points, Active, Championship Years, Decade, Pole_Rate, Start_Rate, Win_Rate, Podium_Rate, FastLap_Rate, Points_Per_Entry, Years_Active, Champion]
# Index: []
