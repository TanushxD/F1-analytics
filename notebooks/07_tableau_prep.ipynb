# %%
import sys, os
sys.path.append(os.path.abspath(".."))

# %load_ext autoreload
# %autoreload 2

import pandas as pd
pd.set_option('display.max_columns', None)

# %%
from src.tableau_export import export_to_hyper

export_to_hyper()
# Out:
# 2026-08-10 22:40:42,088 | INFO | Pulled 25121 rows from vw_tableau_main
# 2026-08-10 22:40:46,026 | INFO | Hyper extract written to C:\Users\tanus\Music\F1-analytics\dashboards\tableau\f1_main_extract.hyper
