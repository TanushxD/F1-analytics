# %%
import sys, os
sys.path.append(os.path.abspath(".."))

# %load_ext autoreload
# %autoreload 2

import pandas as pd
pd.set_option('display.max_columns', None)

# %%
from sqlalchemy import text
from src.db import engine

with open("../sql/analytics_queries/01_championship_progression.sql") as f:
    query = f.read()

result_df = pd.read_sql(text(query), engine)
result_df.head(20)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 from sqlalchemy import text
# ----> 2 from src.db import engine
#       3
#       4 with open("../sql/analytics_queries/01_championship_progression.sql") as f:
#       5     query = f.read()
#
# ModuleNotFoundError: No module named 'src'
